# %% [markdown]
# <a href="https://colab.research.google.com/github/G25ait2026/AIcopy/blob/main/testroll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello  everyone")
# Out:
# hello

# %%
print("hello anjali")
# Out:
# hello anjali
